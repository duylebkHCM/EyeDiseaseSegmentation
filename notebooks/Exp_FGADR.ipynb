# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %cd Thesis/eyediease/
# Out:
# /content/drive/MyDrive/Colab Notebooks/Thesis/eyediease

# %%
# !pip install -q catalyst==20.12
# !pip install -q pytorch-toolbelt==0.4.2
# !pip install -q segmentation-models-pytorch==0.1.3
# !pip install -q albumentations==0.4.6

# %%
from pathlib import Path
import os
import torch
from torch.optim import SGD, Adam, RMSprop, AdamW
from torch.optim.lr_scheduler import (
    ExponentialLR,
    CyclicLR,
    MultiStepLR,
    CosineAnnealingLR,
    CosineAnnealingWarmRestarts,
    ReduceLROnPlateau
)
from torch.utils.data import Dataset, DataLoader
from catalyst import dl
from catalyst.dl import SupervisedRunner, CriterionCallback, EarlyStoppingCallback, SchedulerCallback, MetricAggregationCallback, IouCallback, DiceCallback
from catalyst import utils
from pytorch_toolbelt.losses import *
from catalyst.core import Callback, CallbackOrder
from sklearn.metrics import average_precision_score, roc_auc_score, roc_curve, precision_recall_curve, auc
from torch import Tensor

import albumentations as A
import segmentation_models_pytorch as smp

from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split

from collections import OrderedDict

# %%
img_path = Path(os.getcwd()) / 'data/raw/FGADR/Seg-set/Original_Images'
ex_path = Path(os.getcwd()) / 'data/raw/FGADR/Seg-set/HardExudate_Masks'

# %%
print(len(list(img_path.glob('*.png'))))
print(len(list(ex_path.glob('*.png'))))
# Out:
# 1842
# 1842

# %%
train_idx, test_idx = train_test_split(range(1842), test_size=0.2, random_state=1999)

# %%
train_idx, val_idx = train_test_split(range(len(train_idx)), test_size=0.2, random_state=1999)

# %%
class Lesion(Dataset):
  def __init__(self, img_path, ex_path, transform, preprocessing_fn):
    self.img_path = img_path
    self.ex_path = ex_path
    self.transform = transform
    self.preprocessing_fn = preprocessing_fn

  def __len__(self):
    return len(self.img_path)

  def __getitem__(self, idx):
    img = Image.open(self.img_path[idx])
    mask = Image.open(self.ex_path[idx])
    mask = mask.convert('1')
    img = np.asarray(img)
    mask = np.asarray(mask).astype(np.float32)

    if self.transform:
      result = self.transform(image=img, mask=mask)
      img = result['image']
      mask = result['mask']
    if self.preprocessing_fn:
      img = self.preprocessing_fn(img)
    
    img = torch.FloatTensor(img).permute(2, 0, 1)
    mask = torch.FloatTensor(mask)
    mask = torch.unsqueeze(mask, dim=0)
    filename = self.img_path[idx].name

    return {
        'image': img,
        'target': mask,
        'image_id': filename
    }

# %%
images = sorted(list(img_path.glob('*.png')))
mask = sorted(list(ex_path.glob('*.png')))

images = np.array(images)
mask = np.array(mask)

train_imgs = images[train_idx]
train_mask = mask[train_idx]

val_imgs = images[val_idx]
val_mask = mask[val_idx]

test_imgs = images[test_idx]
test_mask = mask[test_idx]

# %%
print(len(train_imgs), len(train_mask))
print(len(val_imgs), len(val_mask))
print(len(test_imgs), len(test_mask))
# Out:
# 1178 1178
# 295 295
# 369 369

# %%
base_train_transform = A.Compose([
                                  A.HorizontalFlip(),
                                  A.RandomRotate90(),
                                  A.RandomResizedCrop(1280, 1280),
                                  A.Resize(1024, 1024)
])

base_val_transform = A.Compose([A.Resize(1024, 1024)])

# %%
def get_preprocessing_fn(dataset_name: str):
    if dataset_name == "IDRiD":
        mean = [0.44976714,0.2186806,0.06459363]
        std = [0.33224553,0.17116262,0.086509705]
    elif dataset_name == 'FGADR':
        mean = [0.4554011,0.2591345,0.13285689]
        std = [0.28593522,0.185085,0.13528904]
    else:
        mean, std = None, None

    def preprocessing(x, mean=mean, std=std, **kwargs):
        x = x / 255.0
        if mean is not None:
            mean = np.array(mean)
            x = x - mean

        if std is not None:
            std = np.array(std)
            x = x / std
        return x

    return preprocessing

# %%
preprocessing_fn = get_preprocessing_fn('FGADR')

# %%
train_ds = Lesion(list(train_imgs), list(train_mask), base_train_transform, preprocessing_fn)
train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)
val_ds = Lesion(list(val_imgs), list(val_mask), base_val_transform, preprocessing_fn)
val_loader = DataLoader(val_ds, batch_size=4, shuffle=False, num_workers=2, pin_memory=True)

# %%
loader = OrderedDict()
loader['train'] = train_loader
loader['valid'] = val_loader

# %%
model = smp.Unet(encoder_name='resnet50', encoder_weights='imagenet', encoder_depth=5, decoder_use_batchnorm=True, decoder_attention_type='scse', in_channels=3, classes=1)

# %%
param_group = []
if hasattr(model, 'encoder'):
    encoder_params = filter(lambda p: p.requires_grad, model.encoder.parameters())
    param_group += [{'params': encoder_params, 'lr': 1e-5}]        
if hasattr(model, 'decoder'):
    decoder_params = filter(lambda p: p.requires_grad, model.decoder.parameters())
    param_group += [{'params': decoder_params}]        
if hasattr(model, 'segmentation_head'):
    head_params = filter(lambda p: p.requires_grad, model.segmentation_head.parameters())
    param_group += [{'params': head_params}]        

optimizer = AdamW(param_group, 1e-3, weight_decay=1e-5)

# %%
scheduler = MultiStepLR(optimizer, milestones=[int(60 * 0.4), int(60 * 0.7)], gamma=0.1)

# %%
from pytorch_toolbelt.utils import to_numpy
from pytorch_toolbelt.utils.distributed import all_gather
from typing import Callable, Optional

class AucPRMetricCallback(Callback):
    """
    Auc Precision-Recall score metric
    """

    def __init__(
        self,
        outputs_to_probas: Callable[[Tensor], Tensor] = torch.sigmoid,
        input_key: str = "targets",
        output_key: str = "logits",
        prefix: str = "auc_pr",
        average="macro",
        ignore_index: Optional[int] = None,
    ):
        """
        Args:
            input_key: input key to use for accuracy calculation;
                specifies our `y_true`
            output_key: output key to use for accuracy calculation;
                specifies our `y_pred`
            prefix: key for the metric's name
        """

        super().__init__(CallbackOrder.Metric)
        self.prefix = prefix
        self.output_key = output_key
        self.input_key = input_key
        self.ignore_index = ignore_index
        self.outputs_to_probas = outputs_to_probas
        self.y_trues = []
        self.y_preds = []
        self.average = average

    def on_loader_start(self, state):
        self.y_trues = []
        self.y_preds = []

    @torch.no_grad()
    def on_batch_end(self, runner):
        pred_probas = self.outputs_to_probas(runner.output[self.output_key])
        true_labels = runner.input[self.input_key]

        self.y_trues.extend(to_numpy(true_labels))
        self.y_preds.extend(to_numpy(pred_probas))

    def on_loader_end(self, runner):
        y_trues = np.concatenate(all_gather(self.y_trues))
        y_preds = np.concatenate(all_gather(self.y_preds))
        precision, recall, _ = precision_recall_curve(y_trues.reshape(-1), y_preds.reshape(-1))
        score = auc(recall, precision)
        runner.loader_metrics[self.prefix] = float(score)

# %%
criterion = {}
criterion['bce'] = SoftBCEWithLogitsLoss()
criterion['log_dice'] = DiceLoss(mode="binary", log_loss=True)

# %%
callbacks = []
criterion_config = {'bce':0.8, 'log_dice':0.2}
losses = []
for loss_name, loss_weight in criterion_config.items():
    criterion_callback = CriterionCallback(
        input_key="target",
        output_key="logits",
        criterion_key=loss_name,
        prefix="loss_"+loss_name,
        multiplier=float(loss_weight)
    )

    callbacks.append(criterion_callback)
    losses.append(criterion_callback.prefix)

callbacks += [MetricAggregationCallback(
    prefix="loss",
    mode="sum",
    metrics=losses
)]

early_stopping = EarlyStoppingCallback(
        patience=10, metric='dice', minimize=False)

# iou_scores = IouCallback(
#     input_key="target",
#     activation="Sigmoid",
#     threshold=0.5
# )

dice_scores = DiceCallback(
    input_key="target",
    activation="Sigmoid",
threshold=0.5
)

# aucpr_scores = AucPRMetricCallback(
#     input_key="target",
# )

# %%
callbacks += [ early_stopping,
               dice_scores]

# %%
log_dir = 'test_fgadr_2'
os.makedirs(log_dir, exist_ok=False)

# %%
runner = SupervisedRunner(
    device=utils.get_device(), input_key="image", input_target_key="target")

runner.train( 
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    callbacks=callbacks,
    logdir=log_dir,
    loaders=loader,
    num_epochs=60,
    scheduler=scheduler,
    main_metric='dice',
    minimize_metric=False,
    timeit=True,
    fp16=dict(amp=True),
    resume=None,
    verbose=True
)
# Out:
# 1/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.225, dice=0.285, loss=0.324, loss_bce=0.062, loss_log_dice=0.262]
# 1/60 * Epoch (valid): 100% 74/74 [01:55<00:00,  1.57s/it, _timer/_fps=13.361, dice=0.177, loss=0.366, loss_bce=0.005, loss_log_dice=0.361]
# [2021-04-21 16:17:45,046]
# 1/60 * Epoch 1 (_base): lr=1.000e-05 | momentum=0.9000
# 1/60 * Epoch 1 (train): _timer/_fps=3.1943 | _timer/batch_time=1.2530 | _timer/data_time=0.9498 | _timer/model_time=0.3032 | dice=0.2956 | loss=0.4275 | loss_bce=0.0751 | loss_log_dice=0.3524
# 1/60 * Epoch 1 (valid): _timer/_fps=7.7263 | _timer/batch_time=1.5703 | _timer/data_time=1.2840 | _timer/model_time=0.2864 | dice=0.3647 | loss=0.2856 | loss_bce=0.0350 | loss_log_dice=0.2506
# 2/60 * Epoch (train): 100% 294/294 [06:16<00:00,  1.28s/it, _timer/_fps=3.199, dice=0.646, loss=0.108, loss_bce=0.014, loss_log_dice=0.094]
# 2/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.751, dice=0.226, loss=0.338, loss_bce=0.004, loss_log_dice=0.334]
# [2021-04-21 16:24:47,442]
# 2/60 * Epoch 2 (_base): lr=1.000e-05 | momentum=0.9000
# 2/60 * Epoch 2 (train): _timer/_fps=3.1744 | _timer/batch_time=1.2772 | _timer/data_time=0.9736 | _timer/model_time=0.3036 | dice=0.3584 | loss=0.3039 | loss_bce=0.0489 | loss_log_dice=0.2550
# 2/60 * Epoch 2 (valid): _timer/_fps=9.6712 | _timer/batch_time=0.4899 | _timer/data_time=0.2167 | _timer/model_time=0.2732 | dice=0.4040 | loss=0.2519 | loss_bce=0.0277 | loss_log_dice=0.2241
# 3/60 * Epoch (train): 100% 294/294 [06:11<00:00,  1.26s/it, _timer/_fps=3.210, dice=0.401, loss=0.219, loss_bce=0.029, loss_log_dice=0.190]
# 3/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.05it/s, _timer/_fps=12.972, dice=0.263, loss=0.302, loss_bce=0.003, loss_log_dice=0.298]
# [2021-04-21 16:31:49,540]
# 3/60 * Epoch 3 (_base): lr=1.000e-05 | momentum=0.9000
# 3/60 * Epoch 3 (train): _timer/_fps=3.1797 | _timer/batch_time=1.2592 | _timer/data_time=0.9551 | _timer/model_time=0.3041 | dice=0.3966 | loss=0.2602 | loss_bce=0.0459 | loss_log_dice=0.2143
# 3/60 * Epoch 3 (valid): _timer/_fps=8.9261 | _timer/batch_time=0.4868 | _timer/data_time=0.2152 | _timer/model_time=0.2715 | dice=0.4259 | loss=0.2395 | loss_bce=0.0227 | loss_log_dice=0.2169
# 4/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.228, dice=0.643, loss=0.140, loss_bce=0.046, loss_log_dice=0.094]
# 4/60 * Epoch (valid): 100% 74/74 [00:35<00:00,  2.06it/s, _timer/_fps=13.176, dice=0.261, loss=0.297, loss_bce=0.004, loss_log_dice=0.293]
# [2021-04-21 16:38:50,911]
# 4/60 * Epoch 4 (_base): lr=1.000e-05 | momentum=0.9000
# 4/60 * Epoch 4 (train): _timer/_fps=3.1838 | _timer/batch_time=1.2572 | _timer/data_time=0.9532 | _timer/model_time=0.3041 | dice=0.4088 | loss=0.2534 | loss_bce=0.0410 | loss_log_dice=0.2124
# 4/60 * Epoch 4 (valid): _timer/_fps=9.1763 | _timer/batch_time=0.4862 | _timer/data_time=0.2138 | _timer/model_time=0.2724 | dice=0.4375 | loss=0.2372 | loss_bce=0.0220 | loss_log_dice=0.2153
# 5/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.199, dice=0.367, loss=0.235, loss_bce=0.027, loss_log_dice=0.209]
# 5/60 * Epoch (valid):   0% 0/74 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# 5/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.03it/s, _timer/_fps=13.942, dice=0.306, loss=0.260, loss_bce=0.004, loss_log_dice=0.256]
# [2021-04-21 16:45:52,763]
# 5/60 * Epoch 5 (_base): lr=1.000e-05 | momentum=0.9000
# 5/60 * Epoch 5 (train): _timer/_fps=3.1858 | _timer/batch_time=1.2570 | _timer/data_time=0.9533 | _timer/model_time=0.3037 | dice=0.4202 | loss=0.2443 | loss_bce=0.0419 | loss_log_dice=0.2023
# 5/60 * Epoch 5 (valid): _timer/_fps=9.8458 | _timer/batch_time=0.4937 | _timer/data_time=0.2213 | _timer/model_time=0.2724 | dice=0.4797 | loss=0.2121 | loss_bce=0.0212 | loss_log_dice=0.1909
# 6/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.197, dice=0.431, loss=0.194, loss_bce=0.017, loss_log_dice=0.178]
# 6/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.807, dice=0.294, loss=0.277, loss_bce=0.003, loss_log_dice=0.274]
# [2021-04-21 16:52:54,561]
# 6/60 * Epoch 6 (_base): lr=1.000e-05 | momentum=0.9000
# 6/60 * Epoch 6 (train): _timer/_fps=3.1830 | _timer/batch_time=1.2579 | _timer/data_time=0.9539 | _timer/model_time=0.3040 | dice=0.4271 | loss=0.2350 | loss_bce=0.0406 | loss_log_dice=0.1944
# 6/60 * Epoch 6 (valid): _timer/_fps=9.4128 | _timer/batch_time=0.4903 | _timer/data_time=0.2186 | _timer/model_time=0.2717 | dice=0.4968 | loss=0.1986 | loss_bce=0.0197 | loss_log_dice=0.1789
# 7/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.225, dice=0.585, loss=0.125, loss_bce=0.010, loss_log_dice=0.114]
# 7/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=14.029, dice=0.329, loss=0.233, loss_bce=0.004, loss_log_dice=0.229]
# [2021-04-21 16:59:55,735]
# 7/60 * Epoch 7 (_base): lr=1.000e-05 | momentum=0.9000
# 7/60 * Epoch 7 (train): _timer/_fps=3.1823 | _timer/batch_time=1.2581 | _timer/data_time=0.9540 | _timer/model_time=0.3041 | dice=0.4260 | loss=0.2499 | loss_bce=0.0427 | loss_log_dice=0.2072
# 7/60 * Epoch 7 (valid): _timer/_fps=9.5462 | _timer/batch_time=0.4901 | _timer/data_time=0.2177 | _timer/model_time=0.2724 | dice=0.4933 | loss=0.1901 | loss_bce=0.0259 | loss_log_dice=0.1642
# 8/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.207, dice=0.602, loss=0.121, loss_bce=0.015, loss_log_dice=0.106]
# 8/60 * Epoch (valid): 100% 74/74 [00:35<00:00,  2.06it/s, _timer/_fps=12.989, dice=0.310, loss=0.246, loss_bce=0.004, loss_log_dice=0.241]
# [2021-04-21 17:06:47,128]
# 8/60 * Epoch 8 (_base): lr=1.000e-05 | momentum=0.9000
# 8/60 * Epoch 8 (train): _timer/_fps=3.1882 | _timer/batch_time=1.2549 | _timer/data_time=0.9514 | _timer/model_time=0.3035 | dice=0.4752 | loss=0.2099 | loss_bce=0.0331 | loss_log_dice=0.1769
# 8/60 * Epoch 8 (valid): _timer/_fps=9.3180 | _timer/batch_time=0.4854 | _timer/data_time=0.2132 | _timer/model_time=0.2722 | dice=0.4897 | loss=0.1929 | loss_bce=0.0224 | loss_log_dice=0.1704
# 9/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.199, dice=0.643, loss=0.138, loss_bce=0.046, loss_log_dice=0.092]
# 9/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.973, dice=0.411, loss=0.197, loss_bce=0.003, loss_log_dice=0.194]
# [2021-04-21 17:13:39,311]
# 9/60 * Epoch 9 (_base): lr=1.000e-05 | momentum=0.9000
# 9/60 * Epoch 9 (train): _timer/_fps=3.1854 | _timer/batch_time=1.2559 | _timer/data_time=0.9525 | _timer/model_time=0.3034 | dice=0.4630 | loss=0.2193 | loss_bce=0.0349 | loss_log_dice=0.1844
# 9/60 * Epoch 9 (valid): _timer/_fps=9.7852 | _timer/batch_time=0.4912 | _timer/data_time=0.2185 | _timer/model_time=0.2727 | dice=0.5063 | loss=0.1857 | loss_bce=0.0210 | loss_log_dice=0.1647
# 10/60 * Epoch (train): 100% 294/294 [06:11<00:00,  1.26s/it, _timer/_fps=3.226, dice=0.270, loss=0.282, loss_bce=0.008, loss_log_dice=0.274]
# 10/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.01it/s, _timer/_fps=13.763, dice=0.370, loss=0.229, loss_bce=0.003, loss_log_dice=0.226]
# [2021-04-21 17:20:42,148]
# 10/60 * Epoch 10 (_base): lr=1.000e-05 | momentum=0.9000
# 10/60 * Epoch 10 (train): _timer/_fps=3.1772 | _timer/batch_time=1.2597 | _timer/data_time=0.9557 | _timer/model_time=0.3040 | dice=0.4695 | loss=0.2340 | loss_bce=0.0363 | loss_log_dice=0.1977
# 10/60 * Epoch 10 (valid): _timer/_fps=9.7730 | _timer/batch_time=0.4971 | _timer/data_time=0.2236 | _timer/model_time=0.2735 | dice=0.5239 | loss=0.1828 | loss_bce=0.0213 | loss_log_dice=0.1614
# 11/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.231, dice=0.215, loss=0.335, loss_bce=0.006, loss_log_dice=0.329]
# 11/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.02it/s, _timer/_fps=13.823, dice=0.463, loss=0.171, loss_bce=0.002, loss_log_dice=0.169]
# [2021-04-21 17:27:44,257]
# 11/60 * Epoch 11 (_base): lr=1.000e-05 | momentum=0.9000
# 11/60 * Epoch 11 (train): _timer/_fps=3.1825 | _timer/batch_time=1.2577 | _timer/data_time=0.9540 | _timer/model_time=0.3037 | dice=0.4730 | loss=0.2184 | loss_bce=0.0343 | loss_log_dice=0.1841
# 11/60 * Epoch 11 (valid): _timer/_fps=9.6987 | _timer/batch_time=0.4944 | _timer/data_time=0.2209 | _timer/model_time=0.2735 | dice=0.5327 | loss=0.1697 | loss_bce=0.0197 | loss_log_dice=0.1500
# 12/60 * Epoch (train): 100% 294/294 [06:14<00:00,  1.27s/it, _timer/_fps=3.214, dice=0.524, loss=0.184, loss_bce=0.038, loss_log_dice=0.146]
# 12/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.659, dice=0.407, loss=0.210, loss_bce=0.003, loss_log_dice=0.207]
# [2021-04-21 17:34:45,101]
# 12/60 * Epoch 12 (_base): lr=1.000e-05 | momentum=0.9000
# 12/60 * Epoch 12 (train): _timer/_fps=3.1840 | _timer/batch_time=1.2708 | _timer/data_time=0.9674 | _timer/model_time=0.3034 | dice=0.4538 | loss=0.2456 | loss_bce=0.0398 | loss_log_dice=0.2059
# 12/60 * Epoch 12 (valid): _timer/_fps=9.1975 | _timer/batch_time=0.4899 | _timer/data_time=0.2178 | _timer/model_time=0.2721 | dice=0.5145 | loss=0.1804 | loss_bce=0.0184 | loss_log_dice=0.1621
# 13/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.220, dice=0.306, loss=0.254, loss_bce=0.010, loss_log_dice=0.243]
# 13/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.02it/s, _timer/_fps=13.591, dice=0.449, loss=0.178, loss_bce=0.003, loss_log_dice=0.175]
# [2021-04-21 17:41:37,014]
# 13/60 * Epoch 13 (_base): lr=1.000e-05 | momentum=0.9000
# 13/60 * Epoch 13 (train): _timer/_fps=3.1932 | _timer/batch_time=1.2531 | _timer/data_time=0.9500 | _timer/model_time=0.3031 | dice=0.4573 | loss=0.2275 | loss_bce=0.0344 | loss_log_dice=0.1931
# 13/60 * Epoch 13 (valid): _timer/_fps=9.7987 | _timer/batch_time=0.4941 | _timer/data_time=0.2215 | _timer/model_time=0.2726 | dice=0.5107 | loss=0.1769 | loss_bce=0.0211 | loss_log_dice=0.1558
# 14/60 * Epoch (train): 100% 294/294 [06:08<00:00,  1.25s/it, _timer/_fps=3.207, dice=0.267, loss=0.459, loss_bce=0.194, loss_log_dice=0.264]
# 14/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.993, dice=0.497, loss=0.159, loss_bce=0.002, loss_log_dice=0.157]
# [2021-04-21 17:48:27,445]
# 14/60 * Epoch 14 (_base): lr=1.000e-05 | momentum=0.9000
# 14/60 * Epoch 14 (train): _timer/_fps=3.1978 | _timer/batch_time=1.2513 | _timer/data_time=0.9480 | _timer/model_time=0.3033 | dice=0.4838 | loss=0.2103 | loss_bce=0.0329 | loss_log_dice=0.1774
# 14/60 * Epoch 14 (valid): _timer/_fps=9.7709 | _timer/batch_time=0.4894 | _timer/data_time=0.2169 | _timer/model_time=0.2724 | dice=0.4954 | loss=0.2044 | loss_bce=0.0223 | loss_log_dice=0.1820
# 15/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.233, dice=0.633, loss=0.109, loss_bce=0.010, loss_log_dice=0.099]
# 15/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.707, dice=0.462, loss=0.183, loss_bce=0.003, loss_log_dice=0.180]
# [2021-04-21 17:55:18,158]
# 15/60 * Epoch 15 (_base): lr=1.000e-05 | momentum=0.9000
# 15/60 * Epoch 15 (train): _timer/_fps=3.1971 | _timer/batch_time=1.2517 | _timer/data_time=0.9486 | _timer/model_time=0.3031 | dice=0.4676 | loss=0.2245 | loss_bce=0.0340 | loss_log_dice=0.1905
# 15/60 * Epoch 15 (valid): _timer/_fps=9.8477 | _timer/batch_time=0.4897 | _timer/data_time=0.2173 | _timer/model_time=0.2724 | dice=0.5346 | loss=0.1737 | loss_bce=0.0213 | loss_log_dice=0.1524
# 16/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.231, dice=0.588, loss=0.203, loss_bce=0.089, loss_log_dice=0.114]
# 16/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.968, dice=0.430, loss=0.182, loss_bce=0.003, loss_log_dice=0.180]
# [2021-04-21 18:02:18,718]
# 16/60 * Epoch 16 (_base): lr=1.000e-05 | momentum=0.9000
# 16/60 * Epoch 16 (train): _timer/_fps=3.1936 | _timer/batch_time=1.2533 | _timer/data_time=0.9498 | _timer/model_time=0.3036 | dice=0.5021 | loss=0.2063 | loss_bce=0.0307 | loss_log_dice=0.1756
# 16/60 * Epoch 16 (valid): _timer/_fps=9.7948 | _timer/batch_time=0.4906 | _timer/data_time=0.2184 | _timer/model_time=0.2722 | dice=0.5362 | loss=0.1679 | loss_bce=0.0214 | loss_log_dice=0.1465
# 17/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.236, dice=0.114, loss=0.453, loss_bce=0.008, loss_log_dice=0.445]
# 17/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.058, dice=0.380, loss=0.203, loss_bce=0.004, loss_log_dice=0.200]
# [2021-04-21 18:09:19,956]
# 17/60 * Epoch 17 (_base): lr=1.000e-05 | momentum=0.9000
# 17/60 * Epoch 17 (train): _timer/_fps=3.1885 | _timer/batch_time=1.2558 | _timer/data_time=0.9524 | _timer/model_time=0.3034 | dice=0.4636 | loss=0.2325 | loss_bce=0.0352 | loss_log_dice=0.1974
# 17/60 * Epoch 17 (valid): _timer/_fps=9.4176 | _timer/batch_time=0.4898 | _timer/data_time=0.2172 | _timer/model_time=0.2725 | dice=0.5053 | loss=0.1965 | loss_bce=0.0223 | loss_log_dice=0.1742
# 18/60 * Epoch (train): 100% 294/294 [06:08<00:00,  1.25s/it, _timer/_fps=3.244, dice=0.847, loss=0.054, loss_bce=0.015, loss_log_dice=0.039]
# 18/60 * Epoch (valid): 100% 74/74 [00:37<00:00,  1.99it/s, _timer/_fps=13.819, dice=0.395, loss=0.203, loss_bce=0.003, loss_log_dice=0.200]
# [2021-04-21 18:16:11,544]
# 18/60 * Epoch 18 (_base): lr=1.000e-05 | momentum=0.9000
# 18/60 * Epoch 18 (train): _timer/_fps=3.1985 | _timer/batch_time=1.2510 | _timer/data_time=0.9482 | _timer/model_time=0.3028 | dice=0.4908 | loss=0.2124 | loss_bce=0.0314 | loss_log_dice=0.1810
# 18/60 * Epoch 18 (valid): _timer/_fps=9.1310 | _timer/batch_time=0.5037 | _timer/data_time=0.2315 | _timer/model_time=0.2722 | dice=0.5164 | loss=0.1741 | loss_bce=0.0217 | loss_log_dice=0.1524
# 19/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.246, dice=0.353, loss=0.222, loss_bce=0.010, loss_log_dice=0.212]
# 19/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.02it/s, _timer/_fps=13.616, dice=0.445, loss=0.180, loss_bce=0.003, loss_log_dice=0.177]
# [2021-04-21 18:23:03,078]
# 19/60 * Epoch 19 (_base): lr=1.000e-05 | momentum=0.9000
# 19/60 * Epoch 19 (train): _timer/_fps=3.1920 | _timer/batch_time=1.2536 | _timer/data_time=0.9510 | _timer/model_time=0.3025 | dice=0.4836 | loss=0.2124 | loss_bce=0.0319 | loss_log_dice=0.1805
# 19/60 * Epoch 19 (valid): _timer/_fps=9.2526 | _timer/batch_time=0.4950 | _timer/data_time=0.2227 | _timer/model_time=0.2723 | dice=0.5312 | loss=0.1683 | loss_bce=0.0197 | loss_log_dice=0.1486
# 20/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.221, dice=0.575, loss=0.178, loss_bce=0.059, loss_log_dice=0.119]
# 20/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.00it/s, _timer/_fps=14.011, dice=0.380, loss=0.207, loss_bce=0.003, loss_log_dice=0.204]
# [2021-04-21 18:29:55,397]
# 20/60 * Epoch 20 (_base): lr=1.000e-05 | momentum=0.9000
# 20/60 * Epoch 20 (train): _timer/_fps=3.1911 | _timer/batch_time=1.2538 | _timer/data_time=0.9512 | _timer/model_time=0.3026 | dice=0.4973 | loss=0.1966 | loss_bce=0.0292 | loss_log_dice=0.1674
# 20/60 * Epoch 20 (valid): _timer/_fps=9.7607 | _timer/batch_time=0.4988 | _timer/data_time=0.2259 | _timer/model_time=0.2729 | dice=0.5476 | loss=0.1625 | loss_bce=0.0193 | loss_log_dice=0.1431
# 21/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.221, dice=0.663, loss=0.159, loss_bce=0.073, loss_log_dice=0.086]
# 21/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.01it/s, _timer/_fps=13.573, dice=0.449, loss=0.174, loss_bce=0.003, loss_log_dice=0.172]
# [2021-04-21 18:36:57,114]
# 21/60 * Epoch 21 (_base): lr=1.000e-05 | momentum=0.9000
# 21/60 * Epoch 21 (train): _timer/_fps=3.1894 | _timer/batch_time=1.2558 | _timer/data_time=0.9520 | _timer/model_time=0.3038 | dice=0.4979 | loss=0.1862 | loss_bce=0.0282 | loss_log_dice=0.1580
# 21/60 * Epoch 21 (valid): _timer/_fps=9.8174 | _timer/batch_time=0.4969 | _timer/data_time=0.2239 | _timer/model_time=0.2730 | dice=0.5294 | loss=0.1696 | loss_bce=0.0184 | loss_log_dice=0.1512
# 22/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.196, dice=0.494, loss=0.181, loss_bce=0.035, loss_log_dice=0.145]
# 22/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.03it/s, _timer/_fps=13.642, dice=0.493, loss=0.157, loss_bce=0.003, loss_log_dice=0.155]
# [2021-04-21 18:43:48,197]
# 22/60 * Epoch 22 (_base): lr=1.000e-05 | momentum=0.9000
# 22/60 * Epoch 22 (train): _timer/_fps=3.1944 | _timer/batch_time=1.2526 | _timer/data_time=0.9498 | _timer/model_time=0.3028 | dice=0.5038 | loss=0.1977 | loss_bce=0.0286 | loss_log_dice=0.1691
# 22/60 * Epoch 22 (valid): _timer/_fps=9.4931 | _timer/batch_time=0.4935 | _timer/data_time=0.2212 | _timer/model_time=0.2723 | dice=0.5170 | loss=0.1819 | loss_bce=0.0218 | loss_log_dice=0.1601
# 23/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.225, dice=0.549, loss=0.131, loss_bce=0.008, loss_log_dice=0.123]
# 23/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.03it/s, _timer/_fps=12.885, dice=0.443, loss=0.172, loss_bce=0.003, loss_log_dice=0.169]
# [2021-04-21 18:50:40,350]
# 23/60 * Epoch 23 (_base): lr=1.000e-05 | momentum=0.9000
# 23/60 * Epoch 23 (train): _timer/_fps=3.1892 | _timer/batch_time=1.2547 | _timer/data_time=0.9517 | _timer/model_time=0.3029 | dice=0.5037 | loss=0.1988 | loss_bce=0.0310 | loss_log_dice=0.1677
# 23/60 * Epoch 23 (valid): _timer/_fps=9.3084 | _timer/batch_time=0.4914 | _timer/data_time=0.2192 | _timer/model_time=0.2722 | dice=0.5239 | loss=0.1851 | loss_bce=0.0221 | loss_log_dice=0.1630
# 24/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.231, dice=0.555, loss=0.153, loss_bce=0.032, loss_log_dice=0.121]
# 24/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=13.967, dice=0.380, loss=0.201, loss_bce=0.004, loss_log_dice=0.197]
# [2021-04-21 18:57:31,379]
# 24/60 * Epoch 24 (_base): lr=1.000e-06 | momentum=0.9000
# 24/60 * Epoch 24 (train): _timer/_fps=3.1944 | _timer/batch_time=1.2527 | _timer/data_time=0.9501 | _timer/model_time=0.3026 | dice=0.5179 | loss=0.1855 | loss_bce=0.0298 | loss_log_dice=0.1557
# 24/60 * Epoch 24 (valid): _timer/_fps=9.1831 | _timer/batch_time=0.4907 | _timer/data_time=0.2188 | _timer/model_time=0.2719 | dice=0.5171 | loss=0.1889 | loss_bce=0.0223 | loss_log_dice=0.1665
# 25/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.226, dice=0.323, loss=0.245, loss_bce=0.018, loss_log_dice=0.226]
# 25/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.00it/s, _timer/_fps=13.838, dice=0.426, loss=0.178, loss_bce=0.003, loss_log_dice=0.175]
# [2021-04-21 19:04:23,109]
# 25/60 * Epoch 25 (_base): lr=1.000e-06 | momentum=0.9000
# 25/60 * Epoch 25 (train): _timer/_fps=3.1928 | _timer/batch_time=1.2533 | _timer/data_time=0.9506 | _timer/model_time=0.3027 | dice=0.5236 | loss=0.1807 | loss_bce=0.0267 | loss_log_dice=0.1540
# 25/60 * Epoch 25 (valid): _timer/_fps=9.5616 | _timer/batch_time=0.4988 | _timer/data_time=0.2263 | _timer/model_time=0.2724 | dice=0.5239 | loss=0.1814 | loss_bce=0.0208 | loss_log_dice=0.1606
# 26/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.211, dice=0.564, loss=0.123, loss_bce=0.004, loss_log_dice=0.119]
# 26/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.01it/s, _timer/_fps=13.785, dice=0.455, loss=0.168, loss_bce=0.003, loss_log_dice=0.165]
# [2021-04-21 19:11:15,311]
# 26/60 * Epoch 26 (_base): lr=1.000e-06 | momentum=0.9000
# 26/60 * Epoch 26 (train): _timer/_fps=3.1911 | _timer/batch_time=1.2538 | _timer/data_time=0.9511 | _timer/model_time=0.3027 | dice=0.5118 | loss=0.1793 | loss_bce=0.0273 | loss_log_dice=0.1521
# 26/60 * Epoch 26 (valid): _timer/_fps=9.5837 | _timer/batch_time=0.4975 | _timer/data_time=0.2258 | _timer/model_time=0.2717 | dice=0.5276 | loss=0.1801 | loss_bce=0.0212 | loss_log_dice=0.1589
# 27/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.243, dice=0.568, loss=0.154, loss_bce=0.038, loss_log_dice=0.116]
# 27/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.04it/s, _timer/_fps=12.866, dice=0.454, loss=0.168, loss_bce=0.003, loss_log_dice=0.165]
# [2021-04-21 19:18:07,971]
# 27/60 * Epoch 27 (_base): lr=1.000e-06 | momentum=0.9000
# 27/60 * Epoch 27 (train): _timer/_fps=3.1860 | _timer/batch_time=1.2559 | _timer/data_time=0.9527 | _timer/model_time=0.3032 | dice=0.5215 | loss=0.1893 | loss_bce=0.0267 | loss_log_dice=0.1626
# 27/60 * Epoch 27 (valid): _timer/_fps=9.1302 | _timer/batch_time=0.4909 | _timer/data_time=0.2180 | _timer/model_time=0.2728 | dice=0.5378 | loss=0.1793 | loss_bce=0.0200 | loss_log_dice=0.1593
# 28/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.206, dice=0.387, loss=0.208, loss_bce=0.010, loss_log_dice=0.199]
# 28/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.02it/s, _timer/_fps=13.357, dice=0.490, loss=0.154, loss_bce=0.003, loss_log_dice=0.152]
# [2021-04-21 19:24:59,868]
# 28/60 * Epoch 28 (_base): lr=1.000e-06 | momentum=0.9000
# 28/60 * Epoch 28 (train): _timer/_fps=3.1885 | _timer/batch_time=1.2549 | _timer/data_time=0.9519 | _timer/model_time=0.3030 | dice=0.5236 | loss=0.1780 | loss_bce=0.0255 | loss_log_dice=0.1525
# 28/60 * Epoch 28 (valid): _timer/_fps=9.5526 | _timer/batch_time=0.4945 | _timer/data_time=0.2236 | _timer/model_time=0.2708 | dice=0.5371 | loss=0.1677 | loss_bce=0.0199 | loss_log_dice=0.1477
# 29/60 * Epoch (train): 100% 294/294 [06:09<00:00,  1.26s/it, _timer/_fps=3.231, dice=0.321, loss=0.240, loss_bce=0.002, loss_log_dice=0.238]
# 29/60 * Epoch (valid): 100% 74/74 [00:36<00:00,  2.02it/s, _timer/_fps=13.943, dice=0.468, loss=0.162, loss_bce=0.003, loss_log_dice=0.159]
# [2021-04-21 19:31:51,798]
# 29/60 * Epoch 29 (_base): lr=1.000e-06 | momentum=0.9000
# 29/60 * Epoch 29 (train): _timer/_fps=3.1886 | _timer/batch_time=1.2550 | _timer/data_time=0.9519 | _timer/model_time=0.3031 | dice=0.5180 | loss=0.1854 | loss_bce=0.0265 | loss_log_dice=0.1589
# 29/60 * Epoch 29 (valid): _timer/_fps=9.6272 | _timer/batch_time=0.4945 | _timer/data_time=0.2214 | _timer/model_time=0.2731 | dice=0.5418 | loss=0.1661 | loss_bce=0.0197 | loss_log_dice=0.1463
# 30/60 * Epoch (train): 100% 294/294 [06:10<00:00,  1.26s/it, _timer/_fps=3.220, dice=0.754, loss=0.073, loss_bce=0.012, loss_log_dice=0.061]
# 30/60 * Epoch (valid): 100% 74/74 [00:37<00:00,  1.98it/s, _timer/_fps=12.930, dice=0.468, loss=0.161, loss_bce=0.003, loss_log_dice=0.159]
# [2021-04-21 19:38:44,815]
# 30/60 * Epoch 30 (_base): lr=1.000e-06 | momentum=0.9000
# 30/60 * Epoch 30 (train): _timer/_fps=3.1868 | _timer/batch_time=1.2556 | _timer/data_time=0.9526 | _timer/model_time=0.3030 | dice=0.5355 | loss=0.1734 | loss_bce=0.0247 | loss_log_dice=0.1487
# 30/60 * Epoch 30 (valid): _timer/_fps=9.3341 | _timer/batch_time=0.5044 | _timer/data_time=0.2326 | _timer/model_time=0.2718 | dice=0.5386 | loss=0.1731 | loss_bce=0.0192 | loss_log_dice=0.1538
# Early stop at 30 epoch
# Top best models:
# test_fgadr_2/checkpoints/train.20.pth	0.5476

# %%
test_ds = Lesion(list(test_imgs), list(test_mask), base_val_transform, preprocessing_fn)
test_loader = DataLoader(test_ds, batch_size=4, num_workers=2)

# %%
dice_score = smp.utils.metrics.Fscore(threshold=0.5)

# %%
predictions = []
for batch_logits in runner.predict_loader(loader=test_loader):
  logits = batch_logits['logits'].detach().cpu()
  batch_predictions = logits.sigmoid()
  predictions.append(batch_predictions)

# %%
test_dice = 0
i = 0
for (batch, prediction) in zip(test_ds, predictions):
  dice_batch = dice_score(prediction, batch['target']).numpy()
  print(dice_batch)
  test_dice += dice_batch
  i +=1

test_dice /= i
# Out:
# 4.454343e-11
# 1.2172855e-11
# 4.157313e-12
# 3.9105273e-12
# 2.1285654e-11
# 0.014533853
# 0.029219348
# 0.0016998027
# 0.01685484
# 2.5680534e-11
# 1.3008977e-11
# 3.4590109e-12
# 7.402473e-12
# 0.10196934
# 0.036270693
# 0.0019421247
# 8.616901e-13
# 4.2269e-12
# 4.9531924e-12
# 1.0411244e-11
# 1.1623852e-11
# 4.131378e-12
# 0.0050251256
# 4.0165484e-12
# 5.095022e-12
# 4.662222e-12
# 0.0515735
# 3.0774912e-12
# 9.443763e-12
# 0.063821524
# 2.8129396e-11
# 1.4146273e-11
# 0.0032785032
# 0.0028781632
# 1.5581179e-11
# 3.940421e-12
# 8.1566066e-11
# 5.0208366e-12
# 1.9116438e-12
# 2.266289e-12
# 6.686727e-12
# 4.3177892e-11
# 9.228497e-12
# 5.062522e-12
# 0.0074025784
# 7.902015e-12
# 1.1997889e-12
# 2.9359952e-11
# 0.088656865
# 0.000733326
# 8.837045e-12
# 1.43266475e-11
# 0.034032684
# 0.0027820012
# 1.530222e-11
# 1.473405e-11
# 0.0050474284
# 6.9637885e-12
# 6.6702243e-12
# 3.7002775e-12
# 4.842615e-12
# 0.0071260273
# 3.7069987e-12
# 3.7328756e-12
# 3.101641e-12
# 2.7410027e-12
# 0.017725058
# 0.005453837
# 9.057971e-12
# 4.30552e-12
# 7.160144e-13
# 1.8319716e-12
# 5.201831e-12
# 1.1818934e-11
# 0.0012527298
# 0.0057698474
# 2.0730973e-12
# 1.1235955e-09
# 1.5612803e-11
# 2.033223e-12
# 0.0037641667
# 0.00043479836
# 0.0011727671
# 3.285583e-12
# 0.0053569037
# 9.34929e-12
# 0.061081577
# 3.534943e-12
# 0.03174868
# 0.00076253415
# 6.18047e-11
# 8.6887767e-13
# 5.143239e-12

# %%
print(test_dice)
# Out:
# 0.0065523723230245965
